# %%
import json
from pathlib import Path

# %%
json_path = Path("../data/Hooktheory.json")
with open(json_path, "r", encoding="utf-8") as f:
    all_data = json.load(f)

# %%
all_data['qveoYyGGodn'].keys(), all_data['qveoYyGGodn']['annotations'].keys()

# %%
all_data['qveoYyGGodn']['tags'], all_data['qveoYyGGodn']['split']

# %%
all_data['qveoYyGGodn']['hooktheory'] # important info: hooktheory.song, artist

# %%
all_data['qveoYyGGodn']['youtube'], all_data['qveoYyGGodn']['alignment']

# %%
all_data['qveoYyGGodn']['annotations'] # important info: annotations.num_beats, meters, keys, melody, harmony

# %%
print('total count:', len(all_data))
print('train count:', len([i for i in all_data.keys() if all_data[i]['split'] == 'TRAIN']))

# %%
# try to extract key fields
{
    "title": all_data['qveoYyGGodn']["hooktheory"]["song"],
    "artist": all_data['qveoYyGGodn']["hooktheory"]["artist"],
    "meter": all_data['qveoYyGGodn']["annotations"]["meters"],
    "key": all_data['qveoYyGGodn']["annotations"]["keys"],
    "melody": all_data['qveoYyGGodn']["annotations"]["melody"],
    "harmony": all_data['qveoYyGGodn']["annotations"]["harmony"],
    "num_beats": all_data['qveoYyGGodn']["annotations"].get("num_beats", None)
}
# Out:
# {'title': 'whataya-want-from-me',
#  'artist': 'adam-lambert',
#  'meter': [{'beat': 0, 'beats_per_bar': 4, 'beat_unit': 4}],
#  'key': [{'beat': 0,
#    'tonic_pitch_class': 2,
#    'scale_degree_intervals': [2, 2, 1, 2, 2, 2]}],
#  'melody': [{'onset': 1, 'offset': 2, 'octave': 0, 'pitch_class': 11},
#   {'onset': 2, 'offset': 3, 'octave': 0, 'pitch_class': 9},
#   {'onset': 3, 'offset': 3.5, 'octave': 0, 'pitch_class': 4},
#   {'onset': 3.5, 'offset': 5.0, 'octave': 0, 'pitch_class': 6},
#   {'onset': 5, 'offset': 5.5, 'octave': 0, 'pitch_class': 11},
#   {'onset': 5.5, 'offset': 6.0, 'octave': 0, 'pitch_class': 9},
#   {'onset': 6, 'offset': 6.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 6.5, 'offset': 7.0, 'octave': 0, 'pitch_class': 9},
#   {'onset': 7, 'offset': 7.5, 'octave': 0, 'pitch_class': 6},
#   {'onset': 7.5, 'offset': 8.5, 'octave': 0, 'pitch_class': 2},
#   {'onset': 9, 'offset': 9.5, 'octave': 0, 'pitch_class': 11},
#   {'onset': 9.5, 'offset': 10.0, 'octave': 0, 'pitch_class': 9},
#   {'onset': 10, 'offset': 10.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 10.5, 'offset': 11.0, 'octave': 0, 'pitch_class': 4},
#   {'onset': 11, 'offset': 11.5, 'octave': 0, 'pitch_class': 4},
#   {'onset': 11.5, 'offset': 13.0, 'octave': 0, 'pitch_class': 6},
#   {'onset': 13.5, 'offset': 13.75, 'octave': 0, 'pitch_class': 6},
#   {'onset': 13.75, 'offset': 14.0, 'octave': 0, 'pitch_class': 4},
#   {'onset': 14, 'offset': 14.5, 'octave': 0, 'pitch_class': 6},
#   {'onset': 14.5, 'offset': 15.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 15.5, 'offset': 16.0, 'octave': 0, 'pitch_class': 2},
#   {'onset': 16, 'offset': 16.5, 'octave': 0, 'pitch_class': 2},
#   {'onset': 17, 'offset': 17.5, 'octave': 0, 'pitch_class': 11},
#   {'onset': 17.5, 'offset': 18.0, 'octave': 0, 'pitch_class': 9},
#   {'onset': 18, 'offset': 19, 'octave': 0, 'pitch_class': 9},
#   {'onset': 19, 'offset': 19.5, 'octave': 0, 'pitch_class': 4},
#   {'onset': 19.5, 'offset': 21.0, 'octave': 0, 'pitch_class': 6},
#   {'onset': 21, 'offset': 21.5, 'octave': 0, 'pitch_class': 11},
#   {'onset': 21.5, 'offset': 22.0, 'octave': 0, 'pitch_class': 11},
#   {'onset': 22, 'offset': 22.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 22.5, 'offset': 23.0, 'octave': 0, 'pitch_class': 9},
#   {'onset': 23, 'offset': 23.5, 'octave': 0, 'pitch_class': 6},
#   {'onset': 23.5, 'offset': 24.5, 'octave': 0, 'pitch_class': 2},
#   {'onset': 25, 'offset': 25.5, 'octave': 0, 'pitch_class': 11},
#   {'onset': 25.5, 'offset': 26.0, 'octave': 0, 'pitch_class': 11},
#   {'onset': 26, 'offset': 26.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 26.5, 'offset': 27.0, 'octave': 0, 'pitch_class': 9},
#   {'onset': 27, 'offset': 27.5, 'octave': 0, 'pitch_class': 7},
#   {'onset': 27.5, 'offset': 28.0, 'octave': 0, 'pitch_class': 7},
#   {'onset': 28, 'offset': 29, 'octave': 0, 'pitch_class': 6},
#   {'onset': 29.75, 'offset': 30.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 31, 'offset': 31.25, 'octave': 0, 'pitch_class': 9},
#   {'onset': 31.25, 'offset': 31.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 31.5, 'offset': 31.75, 'octave': 0, 'pitch_class': 9},
#   {'onset': 31.75, 'offset': 32.25, 'octave': 0, 'pitch_class': 9},
#   {'onset': 32.25, 'offset': 32.5, 'octave': 0, 'pitch_class': 2},
#   {'onset': 32.5, 'offset': 34.0, 'octave': 0, 'pitch_class': 2},
#   {'onset': 35, 'offset': 35.25, 'octave': 0, 'pitch_class': 9},
#   {'onset': 35.25, 'offset': 35.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 35.5, 'offset': 35.75, 'octave': 0, 'pitch_class': 9},
#   {'onset': 35.75, 'offset': 36.25, 'octave': 0, 'pitch_class': 9},
#   {'onset': 36.25, 'offset': 36.5, 'octave': 0, 'pitch_class': 1},
#   {'onset': 36.5, 'offset': 37.5, 'octave': 0, 'pitch_class': 1},
#   {'onset': 37.5, 'offset': 39.0, 'octave': 0, 'pitch_class': 2},
#   {'onset': 39, 'offset': 39.25, 'octave': 0, 'pitch_class': 9},
#   {'onset': 39.25, 'offset': 39.5, 'octave': 0, 'pitch_class': 9},
#   {'onset': 39.5, 'offset': 39.75, 'octave': 0, 'pitch_class': 9},
#   {'onset': 39.75, 'offset': 40.25, 'octave': 0, 'pitch_class': 9},
#   {'onset': 40.25, 'offset': 40.5, 'octave': 0, 'pitch_class': 2},
#   {'onset': 40.5, 'offset': 42.0, 'octave': 0, 'pitch_class': 2}],
#  'harmony': [{'onset': 0,
#    'offset': 2,
#    'root_pitch_class': 7,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 2,
#    'offset': 4,
#    'root_pitch_class': 9,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 4,
#    'offset': 6,
#    'root_pitch_class': 11,
#    'root_position_intervals': [3, 4],
#    'inversion': 0},
#   {'onset': 6,
#    'offset': 8,
#    'root_pitch_class': 2,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 8,
#    'offset': 10,
#    'root_pitch_class': 7,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 10,
#    'offset': 12,
#    'root_pitch_class': 9,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 12,
#    'offset': 14,
#    'root_pitch_class': 11,
#    'root_position_intervals': [3, 4],
#    'inversion': 0},
#   {'onset': 14,
#    'offset': 16,
#    'root_pitch_class': 2,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 16,
#    'offset': 18,
#    'root_pitch_class': 7,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 18,
#    'offset': 20,
#    'root_pitch_class': 9,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 20,
#    'offset': 22,
#    'root_pitch_class': 11,
#    'root_position_intervals': [3, 4],
#    'inversion': 0},
#   {'onset': 22,
#    'offset': 24,
#    'root_pitch_class': 2,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 24,
#    'offset': 26,
#    'root_pitch_class': 7,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 26,
#    'offset': 28,
#    'root_pitch_class': 9,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 28,
#    'offset': 30,
#    'root_pitch_class': 11,
#    'root_position_intervals': [3, 4],
#    'inversion': 0},
#   {'onset': 30,
#    'offset': 32,
#    'root_pitch_class': 2,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 32,
#    'offset': 34,
#    'root_pitch_class': 7,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 34,
#    'offset': 36,
#    'root_pitch_class': 9,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 36,
#    'offset': 38,
#    'root_pitch_class': 11,
#    'root_position_intervals': [3, 4],
#    'inversion': 0},
#   {'onset': 38,
#    'offset': 40,
#    'root_pitch_class': 2,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 40,
#    'offset': 42,
#    'root_pitch_class': 7,
#    'root_position_intervals': [4, 3],
#    'inversion': 0},
#   {'onset': 42,
#    'offset': 44,
#    'root_pitch_class': 9,
#    'root_position_intervals': [4, 3],
#    'inversion': 0}],
#  'num_beats': 44}

# %%
all_data['qveoYyGGodn']["annotations"]["harmony"]
# Out:
# [{'onset': 0,
#   'offset': 2,
#   'root_pitch_class': 7,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 2,
#   'offset': 4,
#   'root_pitch_class': 9,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 4,
#   'offset': 6,
#   'root_pitch_class': 11,
#   'root_position_intervals': [3, 4],
#   'inversion': 0},
#  {'onset': 6,
#   'offset': 8,
#   'root_pitch_class': 2,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 8,
#   'offset': 10,
#   'root_pitch_class': 7,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 10,
#   'offset': 12,
#   'root_pitch_class': 9,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 12,
#   'offset': 14,
#   'root_pitch_class': 11,
#   'root_position_intervals': [3, 4],
#   'inversion': 0},
#  {'onset': 14,
#   'offset': 16,
#   'root_pitch_class': 2,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 16,
#   'offset': 18,
#   'root_pitch_class': 7,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 18,
#   'offset': 20,
#   'root_pitch_class': 9,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 20,
#   'offset': 22,
#   'root_pitch_class': 11,
#   'root_position_intervals': [3, 4],
#   'inversion': 0},
#  {'onset': 22,
#   'offset': 24,
#   'root_pitch_class': 2,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 24,
#   'offset': 26,
#   'root_pitch_class': 7,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 26,
#   'offset': 28,
#   'root_pitch_class': 9,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 28,
#   'offset': 30,
#   'root_pitch_class': 11,
#   'root_position_intervals': [3, 4],
#   'inversion': 0},
#  {'onset': 30,
#   'offset': 32,
#   'root_pitch_class': 2,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 32,
#   'offset': 34,
#   'root_pitch_class': 7,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 34,
#   'offset': 36,
#   'root_pitch_class': 9,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 36,
#   'offset': 38,
#   'root_pitch_class': 11,
#   'root_position_intervals': [3, 4],
#   'inversion': 0},
#  {'onset': 38,
#   'offset': 40,
#   'root_pitch_class': 2,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 40,
#   'offset': 42,
#   'root_pitch_class': 7,
#   'root_position_intervals': [4, 3],
#   'inversion': 0},
#  {'onset': 42,
#   'offset': 44,
#   'root_pitch_class': 9,
#   'root_position_intervals': [4, 3],
#   'inversion': 0}]
